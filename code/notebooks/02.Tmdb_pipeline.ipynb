# %%
import os
import pandas as pd
import requests
import json
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
from dotenv import load_dotenv

# %%
# =========  CONFIG ========= 

load_dotenv()  # loads from .env file

TMDB_API_KEY = os.getenv("TMDB_API_KEY")
TMDB_READ_TOKEN = os.getenv("TMDB_READ_TOKEN")
TMDB_BASE_URL = "https://api.themoviedb.org/3"

SOURCE_SYSTEM_IMDB = 'imdb'
SOURCE_SYSTEM_TMDB = 'tmdb'
RAW_DATA_DIR_IMDB = os.path.join('..', '..', 'data', 'raw', 'imdb')
RAW_DATA_DIR = os.path.join('..', '..', 'data', 'raw', 'tmdb')
LOAD_DIR = os.path.join('..', '..', 'data', 'raw', 'box_office_mapping')

os.makedirs(RAW_DATA_DIR, exist_ok=True)
os.makedirs(LOAD_DIR, exist_ok=True)

DAILY_API_REQUEST_LIMIT = 25000
MAX_THREADS = 10

# %%
# ========= HELP FUNCTIONS ========= 

def get_already_extracted_ids(directory, prefix, extension='.json'):
    extracted_ids = set()
    for root, _, files in os.walk(directory):
        for f in files:
            if f.startswith(prefix) and f.endswith(extension):
                try:
                    parts = f.split('_')
                    if len(parts) >= 4:
                        extracted_ids.add(parts[3])  # Expecting imdb_id like tt1234567
                except Exception as e:
                    print(f"Error parsing filename {f}: {e}")
    return extracted_ids


def make_tmdb_api_call(endpoint, item_id="", params=None):
    url = f"{TMDB_BASE_URL}/movie/{item_id}{endpoint}"
    headers = {
        "Authorization": f"Bearer {TMDB_READ_TOKEN}",
        "Content-Type": "application/json;charset=utf-8"
    }

    if params is None:
        params = {}
    params["api_key"] = TMDB_API_KEY

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"TMDB API call failed for ID {item_id}: {e}")
        return None


def save_json_response(data, id_value, base_dir, filename_prefix=""):
    current_date_time = datetime.now()
    daily_dir = os.path.join(
        base_dir,
        current_date_time.strftime('%Y'),
        current_date_time.strftime('%m'),
        current_date_time.strftime('%d'),
        SOURCE_SYSTEM_TMDB
    )
    os.makedirs(daily_dir, exist_ok=True)

    timestamp_str = current_date_time.strftime("%Y%m%d_%H%M%S")
    filename = f"{filename_prefix}_{id_value}_{timestamp_str}.json"
    file_path = os.path.join(daily_dir, filename)

    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4)
    except Exception as e:
        print(f"Error saving JSON for ID {id_value}: {e}")


def load_imdb_ids(file_path):
    df_imdb_ids = pd.read_csv(file_path)
    return df_imdb_ids['imdb_movie_id'].tolist()


def load_json_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        return json.load(f)

# %%
# =========  HELP FUNCTIONS 2 ========= 

def get_tmdb_id_for_imdb_id(imdb_id, mapping_df):
    """
    Returns the TMDB ID for a given IMDb ID using the mapping DataFrame.
    """
    row = mapping_df[mapping_df['imdb_movie_id'] == imdb_id]
    return row['tmdb_movie_id'].values[0] if not row.empty else None


def get_imdb_id_for_tmdb_id(tmdb_id, mapping_df):
    """
    Returns the IMDb ID for a given TMDB ID using the mapping DataFrame.
    """
    row = mapping_df[mapping_df['tmdb_movie_id'] == tmdb_id]
    return row['imdb_movie_id'].values[0] if not row.empty else None


def get_tmdb_data_for_imdb_id(imdb_id, stats_df):
    """
    Returns a dictionary with TMDB data for a given IMDb ID using the stats DataFrame.
    """
    row = stats_df[stats_df['tmdb_imdb_id'] == imdb_id]
    return row.iloc[0].to_dict() if not row.empty else None

# %%
# =========  API DATA COLLECTION ========= 

def collect_api_data(imdb_ids_list, data_type="mapping"):
    if data_type == "mapping":
        prefix_pattern = f'{SOURCE_SYSTEM_TMDB}_imdb_mapping_tt'
        endpoint = ""
    elif data_type == "stats":
        prefix_pattern = f'{SOURCE_SYSTEM_TMDB}_movie_stats_tt'
        mapping_file = os.path.join(RAW_DATA_DIR, f'{SOURCE_SYSTEM_TMDB}_imdb_2_tmdb_id_mapping.csv')
        if not os.path.exists(mapping_file):
            print("Mapping file not found. Please run the mapping step first.")
            return
        df_mapping = pd.read_csv(mapping_file)
        imdb_tmdb_map = pd.Series(df_mapping.tmdb_movie_id.values, index=df_mapping.imdb_movie_id).to_dict()
    else:
        raise ValueError("Invalid data_type. Must be 'mapping' or 'stats'.")

    already_extracted = get_already_extracted_ids(RAW_DATA_DIR, prefix_pattern)
    ids_to_process = [imdb_id for imdb_id in imdb_ids_list if str(imdb_id) not in already_extracted]
    ids_to_process = ids_to_process[:DAILY_API_REQUEST_LIMIT]

    if not ids_to_process:
        print("No new IDs to process for this data type.")
        return

    current_request_count = 0
    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        futures = {}
        for imdb_id in ids_to_process:
            if data_type == "mapping":
                future = executor.submit(make_tmdb_api_call, endpoint, imdb_id)
            else:
                tmdb_id = imdb_tmdb_map.get(imdb_id)
                if not tmdb_id:
                    print(f"Skipping {imdb_id}: No TMDB ID found.")
                    continue
                future = executor.submit(make_tmdb_api_call, endpoint, tmdb_id)
            futures[future] = imdb_id

        for i, future in enumerate(as_completed(futures), 1):
            imdb_id = futures[future]
            try:
                json_data = future.result()
                if json_data:
                    save_json_response(json_data, imdb_id, RAW_DATA_DIR, prefix_pattern.split('_tt')[0])
                    current_request_count += 1
                else:
                    print(f"[{i}] No data for IMDb ID: {imdb_id}")
            except Exception as e:
                print(f"[{i}] Error processing IMDb ID {imdb_id}: {e}")

            if current_request_count >= DAILY_API_REQUEST_LIMIT:
                print("Daily API request limit reached.")
                break

    print(f"Finished TMDB API Data Collection ({data_type}). Total requests made: {current_request_count}")

# %%
# =========  DATA TRANSFORMATION ========= 

def create_imdb_tmdb_id_mapping(raw_data_directory, output_dir):
    movie_data = []

    for root, _, files in os.walk(raw_data_directory):
        for file_name in files:
            if file_name.startswith(f'{SOURCE_SYSTEM_TMDB}_imdb_mapping_tt') and file_name.endswith(".json"):
                file_path = os.path.join(root, file_name)
                try:
                    data = load_json_file(file_path)
                    imdb_id_from_filename = file_name.split("_")[3]
                    json_tmdb_id = data.get("id")
                    json_imdb_id = data.get("imdb_id")
                    if json_tmdb_id and json_imdb_id and str(json_imdb_id) == imdb_id_from_filename:
                        movie_data.append((json_imdb_id, json_tmdb_id))
                    else:
                        print(f"Mismatch or missing IDs in file {file_name}")
                except Exception as e:
                    print(f"Error processing JSON file {file_name}: {e}")

    df_mapping = pd.DataFrame(movie_data, columns=['imdb_movie_id', 'tmdb_movie_id']).drop_duplicates()
    df_mapping = df_mapping.sort_values('imdb_movie_id').reset_index(drop=True)

    output_file_path = os.path.join(output_dir, f'{SOURCE_SYSTEM_TMDB}_imdb_2_tmdb_id_mapping.csv')
    df_mapping.to_csv(output_file_path, index=False)
    return df_mapping


def transform_tmdb_api_responses(raw_data_directory, output_dir):
    all_extracted_data = []

    for root, _, files in os.walk(raw_data_directory):
        for file_name in files:
            if file_name.startswith(f'{SOURCE_SYSTEM_TMDB}_movie_stats_tt') and file_name.endswith('.json'):
                file_path = os.path.join(root, file_name)
                try:
                    data = load_json_file(file_path)
                    entry = {
                        "tmdb_budget": data.get("budget"),
                        "tmdb_id": data.get("id"),
                        "tmdb_imdb_id": data.get("imdb_id"),
                        "tmdb_release_date": data.get("release_date"),
                        "tmdb_revenue": data.get("revenue"),
                        "tmdb_vote_average": data.get("vote_average"),
                        "tmdb_vote_count": data.get("vote_count")
                    }
                    all_extracted_data.append(entry)
                except Exception as e:
                    print(f"Error processing JSON file {file_name}: {e}")

    if not all_extracted_data:
        print("No data found to transform.")
        return None

    df_transformed = pd.DataFrame(all_extracted_data)
    df_transformed = df_transformed.drop_duplicates(subset=['tmdb_imdb_id']).reset_index(drop=True)

    output_file_path = os.path.join(output_dir, f'{SOURCE_SYSTEM_TMDB}_movie_box_office.csv')
    df_transformed.to_csv(output_file_path, index=False)
    return df_transformed

# %%
# ========= MAIN EXECUTION FLOW ========= 

if __name__ == "__main__":
    source_file_imdb_ids = os.path.join(RAW_DATA_DIR_IMDB, f'{SOURCE_SYSTEM_IMDB}_movie_ids.csv')
    if not os.path.exists(source_file_imdb_ids):
        print(f"Error: IMDb movie IDs file not found at {source_file_imdb_ids}.")
    else:
        imdb_ids = load_imdb_ids(source_file_imdb_ids)

        print("Starting TMDB Mapping Collection...")
        collect_api_data(imdb_ids, data_type="mapping")

        print("Creating IMDb-TMDB ID mapping...")
        df_mapping = create_imdb_tmdb_id_mapping(RAW_DATA_DIR, LOAD_DIR)

        print("Starting TMDB Stats Collection...")
        collect_api_data(imdb_ids, data_type="stats")

        print("Transforming TMDB JSON responses...")
        df_stats = transform_tmdb_api_responses(RAW_DATA_DIR, LOAD_DIR)

        # --- Example usage of helper functions ---
        if df_mapping is not None and df_stats is not None and len(imdb_ids) > 0:
            sample_imdb_id = imdb_ids[0]
            tmdb_id = get_tmdb_id_for_imdb_id(sample_imdb_id, df_mapping)
            print(f"Sample IMDb ID: {sample_imdb_id} maps to TMDB ID: {tmdb_id}")

            if tmdb_id:
                imdb_id_back = get_imdb_id_for_tmdb_id(tmdb_id, df_mapping)
                print(f"TMDB ID: {tmdb_id} maps back to IMDb ID: {imdb_id_back}")

            tmdb_data = get_tmdb_data_for_imdb_id(sample_imdb_id, df_stats)
            print(f"TMDB data for IMDb ID {sample_imdb_id}:\n{tmdb_data}")
# Out:
# Starting TMDB Mapping Collection...
# TMDB API call failed for ID tt0118656: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0118656?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0108549: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0108549?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0112912: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0112912?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0154187: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0154187?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0159503: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0159503?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0131597: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0131597?api_key=946e197c2070e68dcce7690ad471f676
# [1] No data for IMDb ID: tt0154187
# [2] No data for IMDb ID: tt0108549
# [3] No data for IMDb ID: tt0112912
# [4] No data for IMDb ID: tt0118656
# [5] No data for IMDb ID: tt0159503
# [6] No data for IMDb ID: tt0131597
# TMDB API call failed for ID tt0151685: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0151685?api_key=946e197c2070e68dcce7690ad471f676
# [7] No data for IMDb ID: tt0151685
# TMDB API call failed for ID tt0156263: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0156263?api_key=946e197c2070e68dcce7690ad471f676
# [8] No data for IMDb ID: tt0156263
# TMDB API call failed for ID tt0160270: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0160270?api_key=946e197c2070e68dcce7690ad471f676
# [9] No data for IMDb ID: tt0160270
# TMDB API call failed for ID tt0168578: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0168578?api_key=946e197c2070e68dcce7690ad471f676
# [10] No data for IMDb ID: tt0168578
# TMDB API call failed for ID tt0115937: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=946e197c2070e68dcce7690ad471f676
# [11] No data for IMDb ID: tt0115937
# TMDB API call failed for ID tt0168847: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0168847?api_key=946e197c2070e68dcce7690ad471f676
# [12] No data for IMDb ID: tt0168847
# TMDB API call failed for ID tt0172182: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0172182?api_key=946e197c2070e68dcce7690ad471f676
# [13] No data for IMDb ID: tt0172182
# TMDB API call failed for ID tt0118710: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0118710?api_key=946e197c2070e68dcce7690ad471f676
# [14] No data for IMDb ID: tt0118710
# TMDB API call failed for ID tt0172693: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0172693?api_key=946e197c2070e68dcce7690ad471f676
# [15] No data for IMDb ID: tt0172693
# TMDB API call failed for ID tt0172854: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0172854?api_key=946e197c2070e68dcce7690ad471f676
# [16] No data for IMDb ID: tt0172854
# TMDB API call failed for ID tt0160480: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0160480?api_key=946e197c2070e68dcce7690ad471f676
# [17] No data for IMDb ID: tt0160480
# TMDB API call failed for ID tt0178691: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0178691?api_key=946e197c2070e68dcce7690ad471f676
# [18] No data for IMDb ID: tt0178691
# TMDB API call failed for ID tt0181430: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0181430?api_key=946e197c2070e68dcce7690ad471f676
# [19] No data for IMDb ID: tt0181430
# TMDB API call failed for ID tt0184009: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0184009?api_key=946e197c2070e68dcce7690ad471f676
# [20] No data for IMDb ID: tt0184009
# TMDB API call failed for ID tt0184387: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0184387?api_key=946e197c2070e68dcce7690ad471f676
# [21] No data for IMDb ID: tt0184387
# TMDB API call failed for ID tt0192789: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0192789?api_key=946e197c2070e68dcce7690ad471f676
# [22] No data for IMDb ID: tt0192789
# TMDB API call failed for ID tt0185367: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0185367?api_key=946e197c2070e68dcce7690ad471f676
# [23] No data for IMDb ID: tt0185367
# TMDB API call failed for ID tt0195108: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0195108?api_key=946e197c2070e68dcce7690ad471f676
# [24] No data for IMDb ID: tt0195108
# TMDB API call failed for ID tt0194357: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0194357?api_key=946e197c2070e68dcce7690ad471f676
# [25] No data for IMDb ID: tt0194357
# TMDB API call failed for ID tt0186221: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0186221?api_key=946e197c2070e68dcce7690ad471f676
# [26] No data for IMDb ID: tt0186221
# TMDB API call failed for ID tt0200525: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0200525?api_key=946e197c2070e68dcce7690ad471f676
# [27] No data for IMDb ID: tt0200525
# TMDB API call failed for ID tt0190331: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0190331?api_key=946e197c2070e68dcce7690ad471f676
# [28] No data for IMDb ID: tt0190331
# TMDB API call failed for ID tt0198460: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0198460?api_key=946e197c2070e68dcce7690ad471f676
# [29] No data for IMDb ID: tt0198460
# TMDB API call failed for ID tt0202316: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0202316?api_key=946e197c2070e68dcce7690ad471f676
# [30] No data for IMDb ID: tt0202316
# TMDB API call failed for ID tt0203144: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0203144?api_key=946e197c2070e68dcce7690ad471f676
# [31] No data for IMDb ID: tt0203144
# TMDB API call failed for ID tt0192110: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0192110?api_key=946e197c2070e68dcce7690ad471f676
# [32] No data for IMDb ID: tt0192110
# TMDB API call failed for ID tt0205521: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0205521?api_key=946e197c2070e68dcce7690ad471f676
# [33] No data for IMDb ID: tt0205521
# TMDB API call failed for ID tt0193365: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0193365?api_key=946e197c2070e68dcce7690ad471f676
# [34] No data for IMDb ID: tt0193365
# TMDB API call failed for ID tt0206324: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0206324?api_key=946e197c2070e68dcce7690ad471f676
# [35] No data for IMDb ID: tt0206324
# TMDB API call failed for ID tt0206068: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0206068?api_key=946e197c2070e68dcce7690ad471f676
# [36] No data for IMDb ID: tt0206068
# TMDB API call failed for ID tt0193537: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0193537?api_key=946e197c2070e68dcce7690ad471f676
# [37] No data for IMDb ID: tt0193537
# TMDB API call failed for ID tt0207002: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0207002?api_key=946e197c2070e68dcce7690ad471f676
# [38] No data for IMDb ID: tt0207002
# TMDB API call failed for ID tt0206806: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0206806?api_key=946e197c2070e68dcce7690ad471f676
# [39] No data for IMDb ID: tt0206806
# TMDB API call failed for ID tt0201275: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0201275?api_key=946e197c2070e68dcce7690ad471f676
# [40] No data for IMDb ID: tt0201275
# TMDB API call failed for ID tt0208412: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0208412?api_key=946e197c2070e68dcce7690ad471f676
# [41] No data for IMDb ID: tt0208412
# TMDB API call failed for ID tt0208910: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0208910?api_key=946e197c2070e68dcce7690ad471f676
# [42] No data for IMDb ID: tt0208910
# TMDB API call failed for ID tt0206211: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0206211?api_key=946e197c2070e68dcce7690ad471f676
# [43] No data for IMDb ID: tt0206211
# TMDB API call failed for ID tt0212873: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0212873?api_key=946e197c2070e68dcce7690ad471f676
# [44] No data for IMDb ID: tt0212873
# TMDB API call failed for ID tt0211279: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0211279?api_key=946e197c2070e68dcce7690ad471f676
# [45] No data for IMDb ID: tt0211279
# TMDB API call failed for ID tt0206670: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0206670?api_key=946e197c2070e68dcce7690ad471f676
# [46] No data for IMDb ID: tt0206670
# TMDB API call failed for ID tt0216256: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0216256?api_key=946e197c2070e68dcce7690ad471f676
# [47] No data for IMDb ID: tt0216256
# TMDB API call failed for ID tt0209005: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0209005?api_key=946e197c2070e68dcce7690ad471f676
# [48] No data for IMDb ID: tt0209005
# TMDB API call failed for ID tt0220605: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0220605?api_key=946e197c2070e68dcce7690ad471f676
# [49] No data for IMDb ID: tt0220605
# TMDB API call failed for ID tt0216290: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0216290?api_key=946e197c2070e68dcce7690ad471f676
# [50] No data for IMDb ID: tt0216290
# TMDB API call failed for ID tt0217884: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0217884?api_key=946e197c2070e68dcce7690ad471f676
# [51] No data for IMDb ID: tt0217884
# TMDB API call failed for ID tt0218561: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0218561?api_key=946e197c2070e68dcce7690ad471f676
# [52] No data for IMDb ID: tt0218561
# TMDB API call failed for ID tt0230212: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0230212?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0224451: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0224451?api_key=946e197c2070e68dcce7690ad471f676
# [53] No data for IMDb ID: tt0230212
# [54] No data for IMDb ID: tt0224451
# TMDB API call failed for ID tt0225518: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0225518?api_key=946e197c2070e68dcce7690ad471f676
# [55] No data for IMDb ID: tt0225518
# TMDB API call failed for ID tt0232149: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0232149?api_key=946e197c2070e68dcce7690ad471f676
# [56] No data for IMDb ID: tt0232149
# TMDB API call failed for ID tt0231514: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0231514?api_key=946e197c2070e68dcce7690ad471f676
# [57] No data for IMDb ID: tt0231514
# TMDB API call failed for ID tt0228761: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0228761?api_key=946e197c2070e68dcce7690ad471f676
# [58] No data for IMDb ID: tt0228761
# TMDB API call failed for ID tt0232994: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0232994?api_key=946e197c2070e68dcce7690ad471f676
# [59] No data for IMDb ID: tt0232994
# TMDB API call failed for ID tt0226591: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0226591?api_key=946e197c2070e68dcce7690ad471f676
# [60] No data for IMDb ID: tt0226591
# TMDB API call failed for ID tt0236261: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0236261?api_key=946e197c2070e68dcce7690ad471f676
# [61] No data for IMDb ID: tt0236261
# TMDB API call failed for ID tt0235877: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0235877?api_key=946e197c2070e68dcce7690ad471f676
# [62] No data for IMDb ID: tt0235877
# TMDB API call failed for ID tt0239115: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0239115?api_key=946e197c2070e68dcce7690ad471f676
# [63] No data for IMDb ID: tt0239115
# TMDB API call failed for ID tt0238373: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0238373?api_key=946e197c2070e68dcce7690ad471f676
# [64] No data for IMDb ID: tt0238373
# TMDB API call failed for ID tt0240903: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0240903?api_key=946e197c2070e68dcce7690ad471f676
# [65] No data for IMDb ID: tt0240903
# TMDB API call failed for ID tt0239541: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0239541?api_key=946e197c2070e68dcce7690ad471f676
# [66] No data for IMDb ID: tt0239541
# TMDB API call failed for ID tt0244158: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0244158?api_key=946e197c2070e68dcce7690ad471f676
# [67] No data for IMDb ID: tt0244158
# TMDB API call failed for ID tt0241250: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0241250?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0241297: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0241297?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0243211: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0243211?api_key=946e197c2070e68dcce7690ad471f676
# [68] No data for IMDb ID: tt0241250
# TMDB API call failed for ID tt0238000: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0238000?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0243291: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0243291?api_key=946e197c2070e68dcce7690ad471f676
# [69] No data for IMDb ID: tt0241297
# [70] No data for IMDb ID: tt0238000
# [71] No data for IMDb ID: tt0243211
# [72] No data for IMDb ID: tt0243291
# TMDB API call failed for ID tt0245320: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0245320?api_key=946e197c2070e68dcce7690ad471f676
# [73] No data for IMDb ID: tt0245320
# TMDB API call failed for ID tt0245438: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0245438?api_key=946e197c2070e68dcce7690ad471f676
# [74] No data for IMDb ID: tt0245438
# TMDB API call failed for ID tt0246409: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0246409?api_key=946e197c2070e68dcce7690ad471f676
# [75] No data for IMDb ID: tt0246409
# TMDB API call failed for ID tt0247294: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0247294?api_key=946e197c2070e68dcce7690ad471f676
# [76] No data for IMDb ID: tt0247294
# TMDB API call failed for ID tt0246047: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0246047?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0246076: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0246076?api_key=946e197c2070e68dcce7690ad471f676
# [77] No data for IMDb ID: tt0246076
# [78] No data for IMDb ID: tt0246047
# TMDB API call failed for ID tt0247906: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0247906?api_key=946e197c2070e68dcce7690ad471f676
# [79] No data for IMDb ID: tt0247906
# TMDB API call failed for ID tt0248233: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0248233?api_key=946e197c2070e68dcce7690ad471f676
# [80] No data for IMDb ID: tt0248233
# TMDB API call failed for ID tt0248017: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0248017?api_key=946e197c2070e68dcce7690ad471f676
# [81] No data for IMDb ID: tt0248017
# TMDB API call failed for ID tt0251462: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0251462?api_key=946e197c2070e68dcce7690ad471f676
# [82] No data for IMDb ID: tt0251462
# TMDB API call failed for ID tt0253933: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0253933?api_key=946e197c2070e68dcce7690ad471f676
# [83] No data for IMDb ID: tt0253933
# TMDB API call failed for ID tt0247585: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0247585?api_key=946e197c2070e68dcce7690ad471f676
# [84] No data for IMDb ID: tt0247585
# TMDB API call failed for ID tt0251796: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0251796?api_key=946e197c2070e68dcce7690ad471f676
# [85] No data for IMDb ID: tt0251796
# TMDB API call failed for ID tt0247389: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0247389?api_key=946e197c2070e68dcce7690ad471f676
# [86] No data for IMDb ID: tt0247389
# TMDB API call failed for ID tt0252630: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0252630?api_key=946e197c2070e68dcce7690ad471f676
# [87] No data for IMDb ID: tt0252630
# TMDB API call failed for ID tt0255439: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0255439?api_key=946e197c2070e68dcce7690ad471f676
# [88] No data for IMDb ID: tt0255439
# TMDB API call failed for ID tt0257947: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0257947?api_key=946e197c2070e68dcce7690ad471f676
# [89] No data for IMDb ID: tt0257947
# TMDB API call failed for ID tt0254541: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0254541?api_key=946e197c2070e68dcce7690ad471f676
# [90] No data for IMDb ID: tt0254541
# TMDB API call failed for ID tt0256160: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0256160?api_key=946e197c2070e68dcce7690ad471f676
# [91] No data for IMDb ID: tt0256160
# TMDB API call failed for ID tt0254724: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0254724?api_key=946e197c2070e68dcce7690ad471f676
# [92] No data for IMDb ID: tt0254724
# TMDB API call failed for ID tt0258604: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0258604?api_key=946e197c2070e68dcce7690ad471f676
# [93] No data for IMDb ID: tt0258604
# TMDB API call failed for ID tt0262174: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0262174?api_key=946e197c2070e68dcce7690ad471f676
# [94] No data for IMDb ID: tt0262174
# TMDB API call failed for ID tt0255099: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0255099?api_key=946e197c2070e68dcce7690ad471f676
# [95] No data for IMDb ID: tt0255099
# TMDB API call failed for ID tt0259117: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0259117?api_key=946e197c2070e68dcce7690ad471f676
# [96] No data for IMDb ID: tt0259117
# TMDB API call failed for ID tt0258512: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0258512?api_key=946e197c2070e68dcce7690ad471f676
# [97] No data for IMDb ID: tt0258512
# TMDB API call failed for ID tt0263029: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0263029?api_key=946e197c2070e68dcce7690ad471f676
# [98] No data for IMDb ID: tt0263029
# TMDB API call failed for ID tt0265235: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0265235?api_key=946e197c2070e68dcce7690ad471f676
# [99] No data for IMDb ID: tt0265235
# TMDB API call failed for ID tt0265688: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0265688?api_key=946e197c2070e68dcce7690ad471f676
# [100] No data for IMDb ID: tt0265688
# TMDB API call failed for ID tt0263263: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0263263?api_key=946e197c2070e68dcce7690ad471f676
# [101] No data for IMDb ID: tt0263263
# TMDB API call failed for ID tt0265281: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0265281?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0265766: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0265766?api_key=946e197c2070e68dcce7690ad471f676
# [102] No data for IMDb ID: tt0265281
# [103] No data for IMDb ID: tt0265766
# TMDB API call failed for ID tt0261202: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0261202?api_key=946e197c2070e68dcce7690ad471f676
# [104] No data for IMDb ID: tt0261202
# TMDB API call failed for ID tt0266238: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0266238?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0266670: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0266670?api_key=946e197c2070e68dcce7690ad471f676
# [105] No data for IMDb ID: tt0266238
# [106] No data for IMDb ID: tt0266670
# TMDB API call failed for ID tt0265273: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0265273?api_key=946e197c2070e68dcce7690ad471f676
# [107] No data for IMDb ID: tt0265273
# TMDB API call failed for ID tt0267667: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0267667?api_key=946e197c2070e68dcce7690ad471f676
# [108] No data for IMDb ID: tt0267667
# TMDB API call failed for ID tt0267314: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0267314?api_key=946e197c2070e68dcce7690ad471f676
# [109] No data for IMDb ID: tt0267314
# TMDB API call failed for ID tt0266339: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0266339?api_key=946e197c2070e68dcce7690ad471f676
# [110] No data for IMDb ID: tt0266339
# TMDB API call failed for ID tt0268992: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0268992?api_key=946e197c2070e68dcce7690ad471f676
# [111] No data for IMDb ID: tt0268992
# TMDB API call failed for ID tt0267749: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0267749?api_key=946e197c2070e68dcce7690ad471f676
# [112] No data for IMDb ID: tt0267749
# TMDB API call failed for ID tt0267263: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0267263?api_key=946e197c2070e68dcce7690ad471f676
# [113] No data for IMDb ID: tt0267263
# TMDB API call failed for ID tt0267764: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0267764?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0269458: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0269458?api_key=946e197c2070e68dcce7690ad471f676
# [114] No data for IMDb ID: tt0267764
# [115] No data for IMDb ID: tt0269458
# TMDB API call failed for ID tt0270023: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0270023?api_key=946e197c2070e68dcce7690ad471f676
# [116] No data for IMDb ID: tt0270023
# TMDB API call failed for ID tt0271547: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0271547?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0271561: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0271561?api_key=946e197c2070e68dcce7690ad471f676
# [117] No data for IMDb ID: tt0271547
# [118] No data for IMDb ID: tt0271561
# TMDB API call failed for ID tt0271071: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0271071?api_key=946e197c2070e68dcce7690ad471f676
# [119] No data for IMDb ID: tt0271071
# TMDB API call failed for ID tt0271742: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0271742?api_key=946e197c2070e68dcce7690ad471f676
# [120] No data for IMDb ID: tt0271742
# TMDB API call failed for ID tt0272217: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0272217?api_key=946e197c2070e68dcce7690ad471f676
# [121] No data for IMDb ID: tt0272217
# TMDB API call failed for ID tt0272543: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0272543?api_key=946e197c2070e68dcce7690ad471f676
# [122] No data for IMDb ID: tt0272543
# TMDB API call failed for ID tt0273884: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0273884?api_key=946e197c2070e68dcce7690ad471f676
# [123] No data for IMDb ID: tt0273884
# TMDB API call failed for ID tt0272178: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0272178?api_key=946e197c2070e68dcce7690ad471f676
# [124] No data for IMDb ID: tt0272178
# TMDB API call failed for ID tt0274491: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0274491?api_key=946e197c2070e68dcce7690ad471f676
# [125] No data for IMDb ID: tt0274491
# TMDB API call failed for ID tt0274708: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0274708?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt0272291: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0272291?api_key=946e197c2070e68dcce7690ad471f676
# [126] No data for IMDb ID: tt0274708
# [127] No data for IMDb ID: tt0272291
# TMDB API call failed for ID tt0274510: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0274510?api_key=946e197c2070e68dcce7690ad471f676
# [128] No data for IMDb ID: tt0274510
# TMDB API call failed for ID tt0276145: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0276145?api_key=946e197c2070e68dcce7690ad471f676
# [129] No data for IMDb ID: tt0276145
# TMDB API call failed for ID tt0275652: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0275652?api_key=946e197c2070e68dcce7690ad471f676
# [130] No data for IMDb ID: tt0275652
# TMDB API call failed for ID tt0276176: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0276176?api_key=946e197c2070e68dcce7690ad471f676
# [131] No data for IMDb ID: tt0276176
# TMDB API call failed for ID tt0278786: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0278786?api_key=946e197c2070e68dcce7690ad471f676
# [132] No data for IMDb ID: tt0278786
# TMDB API call failed for ID tt0277972: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0277972?api_key=946e197c2070e68dcce7690ad471f676
# [133] No data for IMDb ID: tt0277972
# TMDB API call failed for ID tt0276473: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0276473?api_key=946e197c2070e68dcce7690ad471f676
# [134] No data for IMDb ID: tt0276473
# TMDB API call failed for ID tt0279288: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279288?api_key=946e197c2070e68dcce7690ad471f676
# [135] No data for IMDb ID: tt0279288
# TMDB API call failed for ID tt0278905: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0278905?api_key=946e197c2070e68dcce7690ad471f676
# [136] No data for IMDb ID: tt0278905
# TMDB API call failed for ID tt0279088: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279088?api_key=946e197c2070e68dcce7690ad471f676
# [137] No data for IMDb ID: tt0279088
# TMDB API call failed for ID tt0280682: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0280682?api_key=946e197c2070e68dcce7690ad471f676
# [138] No data for IMDb ID: tt0280682
# TMDB API call failed for ID tt0279002: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279002?api_key=946e197c2070e68dcce7690ad471f676
# [139] No data for IMDb ID: tt0279002
# TMDB API call failed for ID tt0279683: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279683?api_key=946e197c2070e68dcce7690ad471f676
# [140] No data for IMDb ID: tt0279683
# TMDB API call failed for ID tt0280883: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0280883?api_key=946e197c2070e68dcce7690ad471f676
# [141] No data for IMDb ID: tt0280883
# TMDB API call failed for ID tt0281312: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0281312?api_key=946e197c2070e68dcce7690ad471f676
# [142] No data for IMDb ID: tt0281312
# TMDB API call failed for ID tt0279620: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279620?api_key=946e197c2070e68dcce7690ad471f676
# [143] No data for IMDb ID: tt0279620
# TMDB API call failed for ID tt0282220: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0282220?api_key=946e197c2070e68dcce7690ad471f676
# [144] No data for IMDb ID: tt0282220
# TMDB API call failed for ID tt0280811: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0280811?api_key=946e197c2070e68dcce7690ad471f676
# [145] No data for IMDb ID: tt0280811
# TMDB API call failed for ID tt0282569: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0282569?api_key=946e197c2070e68dcce7690ad471f676
# [146] No data for IMDb ID: tt0282569
# TMDB API call failed for ID tt0281231: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0281231?api_key=946e197c2070e68dcce7690ad471f676
# [147] No data for IMDb ID: tt0281231
# TMDB API call failed for ID tt0279121: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0279121?api_key=946e197c2070e68dcce7690ad471f676
# [148] No data for IMDb ID: tt0279121
# TMDB API call failed for ID tt0283303: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283303?api_key=946e197c2070e68dcce7690ad471f676
# [149] No data for IMDb ID: tt0283303
# TMDB API call failed for ID tt0283063: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283063?api_key=946e197c2070e68dcce7690ad471f676
# [150] No data for IMDb ID: tt0283063
# TMDB API call failed for ID tt0281551: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0281551?api_key=946e197c2070e68dcce7690ad471f676
# [151] No data for IMDb ID: tt0281551
# TMDB API call failed for ID tt0283432: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283432?api_key=946e197c2070e68dcce7690ad471f676
# [152] No data for IMDb ID: tt0283432
# TMDB API call failed for ID tt0283385: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283385?api_key=946e197c2070e68dcce7690ad471f676
# [153] No data for IMDb ID: tt0283385
# TMDB API call failed for ID tt0282419: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0282419?api_key=946e197c2070e68dcce7690ad471f676
# [154] No data for IMDb ID: tt0282419
# TMDB API call failed for ID tt0283454: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283454?api_key=946e197c2070e68dcce7690ad471f676
# [155] No data for IMDb ID: tt0283454
# TMDB API call failed for ID tt0283560: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283560?api_key=946e197c2070e68dcce7690ad471f676
# [156] No data for IMDb ID: tt0283560
# TMDB API call failed for ID tt0283564: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283564?api_key=946e197c2070e68dcce7690ad471f676
# [157] No data for IMDb ID: tt0283564
# TMDB API call failed for ID tt0284323: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0284323?api_key=946e197c2070e68dcce7690ad471f676
# [158] No data for IMDb ID: tt0284323
# TMDB API call failed for ID tt0283572: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283572?api_key=946e197c2070e68dcce7690ad471f676
# [159] No data for IMDb ID: tt0283572
# TMDB API call failed for ID tt0284673: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0284673?api_key=946e197c2070e68dcce7690ad471f676
# [160] No data for IMDb ID: tt0284673
# TMDB API call failed for ID tt0284341: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0284341?api_key=946e197c2070e68dcce7690ad471f676
# [161] No data for IMDb ID: tt0284341
# TMDB API call failed for ID tt0283659: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0283659?api_key=946e197c2070e68dcce7690ad471f676
# [162] No data for IMDb ID: tt0283659
# TMDB API call failed for ID tt0285668: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0285668?api_key=946e197c2070e68dcce7690ad471f676
# [163] No data for IMDb ID: tt0285668
# TMDB API call failed for ID tt0285056: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0285056?api_key=946e197c2070e68dcce7690ad471f676
# [164] No data for IMDb ID: tt0285056
# TMDB API call failed for ID tt0284566: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0284566?api_key=946e197c2070e68dcce7690ad471f676
# [165] No data for IMDb ID: tt0284566
# TMDB API call failed for ID tt0285973: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0285973?api_key=946e197c2070e68dcce7690ad471f676
# [166] No data for IMDb ID: tt0285973
# TMDB API call failed for ID tt0284999: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0284999?api_key=946e197c2070e68dcce7690ad471f676
# [167] No data for IMDb ID: tt0284999
# TMDB API call failed for ID tt0286713: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0286713?api_key=946e197c2070e68dcce7690ad471f676
# [168] No data for IMDb ID: tt0286713
# TMDB API call failed for ID tt0288257: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0288257?api_key=946e197c2070e68dcce7690ad471f676
# [169] No data for IMDb ID: tt0288257
# TMDB API call failed for ID tt0285221: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0285221?api_key=946e197c2070e68dcce7690ad471f676
# [170] No data for IMDb ID: tt0285221
# TMDB API call failed for ID tt0287147: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0287147?api_key=946e197c2070e68dcce7690ad471f676
# [171] No data for IMDb ID: tt0287147
# TMDB API call failed for ID tt0287006: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0287006?api_key=946e197c2070e68dcce7690ad471f676
# [172] No data for IMDb ID: tt0287006
# TMDB API call failed for ID tt0288247: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0288247?api_key=946e197c2070e68dcce7690ad471f676
# [173] No data for IMDb ID: tt0288247
# TMDB API call failed for ID tt0288484: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0288484?api_key=946e197c2070e68dcce7690ad471f676
# [174] No data for IMDb ID: tt0288484
# TMDB API call failed for ID tt0289272: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0289272?api_key=946e197c2070e68dcce7690ad471f676
# [175] No data for IMDb ID: tt0289272
# TMDB API call failed for ID tt0290219: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0290219?api_key=946e197c2070e68dcce7690ad471f676
# [176] No data for IMDb ID: tt0290219
# TMDB API call failed for ID tt0290083: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0290083?api_key=946e197c2070e68dcce7690ad471f676
# [177] No data for IMDb ID: tt0290083
# TMDB API call failed for ID tt0289275: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0289275?api_key=946e197c2070e68dcce7690ad471f676
# [178] No data for IMDb ID: tt0289275
# TMDB API call failed for ID tt0289366: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0289366?api_key=946e197c2070e68dcce7690ad471f676
# [179] No data for IMDb ID: tt0289366
# TMDB API call failed for ID tt0290669: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0290669?api_key=946e197c2070e68dcce7690ad471f676
# [180] No data for IMDb ID: tt0290669
# TMDB API call failed for ID tt0288865: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0288865?api_key=946e197c2070e68dcce7690ad471f676
# [181] No data for IMDb ID: tt0288865
# TMDB API call failed for ID tt0290705: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0290705?api_key=946e197c2070e68dcce7690ad471f676
# [182] No data for IMDb ID: tt0290705
# TMDB API call failed for ID tt0289768: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0289768?api_key=946e197c2070e68dcce7690ad471f676
# [183] No data for IMDb ID: tt0289768
# TMDB API call failed for ID tt0291433: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291433?api_key=946e197c2070e68dcce7690ad471f676
# [184] No data for IMDb ID: tt0291433
# TMDB API call failed for ID tt0291017: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291017?api_key=946e197c2070e68dcce7690ad471f676
# [185] No data for IMDb ID: tt0291017
# TMDB API call failed for ID tt0290808: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0290808?api_key=946e197c2070e68dcce7690ad471f676
# [186] No data for IMDb ID: tt0290808
# TMDB API call failed for ID tt0291371: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291371?api_key=946e197c2070e68dcce7690ad471f676
# [187] No data for IMDb ID: tt0291371
# TMDB API call failed for ID tt0291770: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291770?api_key=946e197c2070e68dcce7690ad471f676
# [188] No data for IMDb ID: tt0291770
# TMDB API call failed for ID tt0291256: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291256?api_key=946e197c2070e68dcce7690ad471f676
# [189] No data for IMDb ID: tt0291256
# TMDB API call failed for ID tt0294237: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0294237?api_key=946e197c2070e68dcce7690ad471f676
# [190] No data for IMDb ID: tt0294237
# TMDB API call failed for ID tt0292028: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0292028?api_key=946e197c2070e68dcce7690ad471f676
# [191] No data for IMDb ID: tt0292028
# TMDB API call failed for ID tt0291407: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0291407?api_key=946e197c2070e68dcce7690ad471f676
# [192] No data for IMDb ID: tt0291407
# TMDB API call failed for ID tt0292365: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0292365?api_key=946e197c2070e68dcce7690ad471f676
# [193] No data for IMDb ID: tt0292365
# TMDB API call failed for ID tt0294786: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0294786?api_key=946e197c2070e68dcce7690ad471f676
# [194] No data for IMDb ID: tt0294786
# TMDB API call failed for ID tt0294779: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0294779?api_key=946e197c2070e68dcce7690ad471f676
# [195] No data for IMDb ID: tt0294779
# TMDB API call failed for ID tt0293480: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0293480?api_key=946e197c2070e68dcce7690ad471f676
# [196] No data for IMDb ID: tt0293480
# TMDB API call failed for ID tt0295573: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0295573?api_key=946e197c2070e68dcce7690ad471f676
# [197] No data for IMDb ID: tt0295573
# TMDB API call failed for ID tt0293537: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0293537?api_key=946e197c2070e68dcce7690ad471f676
# [198] No data for IMDb ID: tt0293537
# TMDB API call failed for ID tt0295888: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0295888?api_key=946e197c2070e68dcce7690ad471f676
# [199] No data for IMDb ID: tt0295888
# TMDB API call failed for ID tt0296898: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0296898?api_key=946e197c2070e68dcce7690ad471f676
# [200] No data for IMDb ID: tt0296898
# TMDB API call failed for ID tt0294666: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0294666?api_key=946e197c2070e68dcce7690ad471f676
# [201] No data for IMDb ID: tt0294666
# TMDB API call failed for ID tt0296109: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0296109?api_key=946e197c2070e68dcce7690ad471f676
# [202] No data for IMDb ID: tt0296109
# TMDB API call failed for ID tt0296127: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0296127?api_key=946e197c2070e68dcce7690ad471f676
# [203] No data for IMDb ID: tt0296127
# TMDB API call failed for ID tt0298409: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0298409?api_key=946e197c2070e68dcce7690ad471f676
# [204] No data for IMDb ID: tt0298409
# TMDB API call failed for ID tt0297328: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0297328?api_key=946e197c2070e68dcce7690ad471f676
# [205] No data for IMDb ID: tt0297328
# TMDB API call failed for ID tt0296933: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0296933?api_key=946e197c2070e68dcce7690ad471f676
# [206] No data for IMDb ID: tt0296933
# TMDB API call failed for ID tt0298799: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0298799?api_key=946e197c2070e68dcce7690ad471f676
# [207] No data for IMDb ID: tt0298799
# TMDB API call failed for ID tt0298516: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0298516?api_key=946e197c2070e68dcce7690ad471f676
# [208] No data for IMDb ID: tt0298516
# TMDB API call failed for ID tt0297481: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0297481?api_key=946e197c2070e68dcce7690ad471f676
# [209] No data for IMDb ID: tt0297481
# TMDB API call failed for ID tt0299121: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0299121?api_key=946e197c2070e68dcce7690ad471f676
# [210] No data for IMDb ID: tt0299121
# TMDB API call failed for ID tt0299745: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0299745?api_key=946e197c2070e68dcce7690ad471f676
# [211] No data for IMDb ID: tt0299745
# TMDB API call failed for ID tt0298256: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0298256?api_key=946e197c2070e68dcce7690ad471f676
# [212] No data for IMDb ID: tt0298256
# TMDB API call failed for ID tt0299855: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0299855?api_key=946e197c2070e68dcce7690ad471f676
# [213] No data for IMDb ID: tt0299855
# TMDB API call failed for ID tt0300461: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0300461?api_key=946e197c2070e68dcce7690ad471f676
# [214] No data for IMDb ID: tt0300461
# TMDB API call failed for ID tt0298808: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0298808?api_key=946e197c2070e68dcce7690ad471f676
# [215] No data for IMDb ID: tt0298808
# TMDB API call failed for ID tt0299903: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0299903?api_key=946e197c2070e68dcce7690ad471f676
# [216] No data for IMDb ID: tt0299903
# TMDB API call failed for ID tt0300361: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0300361?api_key=946e197c2070e68dcce7690ad471f676
# [217] No data for IMDb ID: tt0300361
# TMDB API call failed for ID tt0301280: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301280?api_key=946e197c2070e68dcce7690ad471f676
# [218] No data for IMDb ID: tt0301280
# TMDB API call failed for ID tt0300634: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0300634?api_key=946e197c2070e68dcce7690ad471f676
# [219] No data for IMDb ID: tt0300634
# TMDB API call failed for ID tt0300106: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0300106?api_key=946e197c2070e68dcce7690ad471f676
# [220] No data for IMDb ID: tt0300106
# TMDB API call failed for ID tt0301342: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301342?api_key=946e197c2070e68dcce7690ad471f676
# [221] No data for IMDb ID: tt0301342
# TMDB API call failed for ID tt0301055: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301055?api_key=946e197c2070e68dcce7690ad471f676
# [222] No data for IMDb ID: tt0301055
# TMDB API call failed for ID tt0301431: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301431?api_key=946e197c2070e68dcce7690ad471f676
# [223] No data for IMDb ID: tt0301431
# TMDB API call failed for ID tt0301670: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301670?api_key=946e197c2070e68dcce7690ad471f676
# [224] No data for IMDb ID: tt0301670
# TMDB API call failed for ID tt0302093: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0302093?api_key=946e197c2070e68dcce7690ad471f676
# [225] No data for IMDb ID: tt0302093
# TMDB API call failed for ID tt0301674: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0301674?api_key=946e197c2070e68dcce7690ad471f676
# [226] No data for IMDb ID: tt0301674
# TMDB API call failed for ID tt0302677: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0302677?api_key=946e197c2070e68dcce7690ad471f676
# [227] No data for IMDb ID: tt0302677
# TMDB API call failed for ID tt0302399: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0302399?api_key=946e197c2070e68dcce7690ad471f676
# [228] No data for IMDb ID: tt0302399
# TMDB API call failed for ID tt0302189: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0302189?api_key=946e197c2070e68dcce7690ad471f676
# [229] No data for IMDb ID: tt0302189
# TMDB API call failed for ID tt0303327: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0303327?api_key=946e197c2070e68dcce7690ad471f676
# [230] No data for IMDb ID: tt0303327
# TMDB API call failed for ID tt0303713: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0303713?api_key=946e197c2070e68dcce7690ad471f676
# [231] No data for IMDb ID: tt0303713
# TMDB API call failed for ID tt0303187: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0303187?api_key=946e197c2070e68dcce7690ad471f676
# [232] No data for IMDb ID: tt0303187
# TMDB API call failed for ID tt0304067: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0304067?api_key=946e197c2070e68dcce7690ad471f676
# [233] No data for IMDb ID: tt0304067
# TMDB API call failed for ID tt0303880: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0303880?api_key=946e197c2070e68dcce7690ad471f676
# [234] No data for IMDb ID: tt0303880
# TMDB API call failed for ID tt0304478: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0304478?api_key=946e197c2070e68dcce7690ad471f676
# [235] No data for IMDb ID: tt0304478
# TMDB API call failed for ID tt0304102: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0304102?api_key=946e197c2070e68dcce7690ad471f676
# [236] No data for IMDb ID: tt0304102
# TMDB API call failed for ID tt0303884: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0303884?api_key=946e197c2070e68dcce7690ad471f676
# [237] No data for IMDb ID: tt0303884
# TMDB API call failed for ID tt0305370: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0305370?api_key=946e197c2070e68dcce7690ad471f676
# [238] No data for IMDb ID: tt0305370
# TMDB API call failed for ID tt0305660: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0305660?api_key=946e197c2070e68dcce7690ad471f676
# [239] No data for IMDb ID: tt0305660
# TMDB API call failed for ID tt0305645: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0305645?api_key=946e197c2070e68dcce7690ad471f676
# [240] No data for IMDb ID: tt0305645
# TMDB API call failed for ID tt0306230: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0306230?api_key=946e197c2070e68dcce7690ad471f676
# [241] No data for IMDb ID: tt0306230
# ...
# [24750] No data for IMDb ID: tt1931482
# TMDB API call failed for ID tt19314942: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19314942?api_key=946e197c2070e68dcce7690ad471f676
# [24755] No data for IMDb ID: tt19314942
# TMDB API call failed for ID tt19315666: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19315666?api_key=946e197c2070e68dcce7690ad471f676
# [24759] No data for IMDb ID: tt19315666
# TMDB API call failed for ID tt19316764: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19316764?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt1932630: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1932630?api_key=946e197c2070e68dcce7690ad471f676
# [24767] No data for IMDb ID: tt19316764
# [24768] No data for IMDb ID: tt1932630
# TMDB API call failed for ID tt1932752: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1932752?api_key=946e197c2070e68dcce7690ad471f676
# [24776] No data for IMDb ID: tt1932752
# TMDB API call failed for ID tt1932694: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1932694?api_key=946e197c2070e68dcce7690ad471f676
# [24780] No data for IMDb ID: tt1932694
# TMDB API call failed for ID tt19339792: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19339792?api_key=946e197c2070e68dcce7690ad471f676
# [24786] No data for IMDb ID: tt19339792
# TMDB API call failed for ID tt1934188: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934188?api_key=946e197c2070e68dcce7690ad471f676
# [24788] No data for IMDb ID: tt1934188
# TMDB API call failed for ID tt1934320: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934320?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt1934323: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934323?api_key=946e197c2070e68dcce7690ad471f676
# [24797] No data for IMDb ID: tt1934320
# [24798] No data for IMDb ID: tt1934323
# TMDB API call failed for ID tt1934418: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934418?api_key=946e197c2070e68dcce7690ad471f676
# [24803] No data for IMDb ID: tt1934418
# TMDB API call failed for ID tt1934423: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934423?api_key=946e197c2070e68dcce7690ad471f676
# [24805] No data for IMDb ID: tt1934423
# TMDB API call failed for ID tt1934416: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934416?api_key=946e197c2070e68dcce7690ad471f676
# [24811] No data for IMDb ID: tt1934416
# TMDB API call failed for ID tt1934450: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1934450?api_key=946e197c2070e68dcce7690ad471f676
# [24814] No data for IMDb ID: tt1934450
# TMDB API call failed for ID tt1935090: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1935090?api_key=946e197c2070e68dcce7690ad471f676
# [24815] No data for IMDb ID: tt1935090
# TMDB API call failed for ID tt1935188: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1935188?api_key=946e197c2070e68dcce7690ad471f676
# [24828] No data for IMDb ID: tt1935188
# TMDB API call failed for ID tt19352296: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19352296?api_key=946e197c2070e68dcce7690ad471f676
# [24829] No data for IMDb ID: tt19352296
# TMDB API call failed for ID tt19351938: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19351938?api_key=946e197c2070e68dcce7690ad471f676
# [24832] No data for IMDb ID: tt19351938
# TMDB API call failed for ID tt19355516: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19355516?api_key=946e197c2070e68dcce7690ad471f676
# [24836] No data for IMDb ID: tt19355516
# TMDB API call failed for ID tt19355752: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19355752?api_key=946e197c2070e68dcce7690ad471f676
# [24838] No data for IMDb ID: tt19355752
# TMDB API call failed for ID tt19355728: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19355728?api_key=946e197c2070e68dcce7690ad471f676
# [24841] No data for IMDb ID: tt19355728
# TMDB API call failed for ID tt19355336: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19355336?api_key=946e197c2070e68dcce7690ad471f676
# [24847] No data for IMDb ID: tt19355336
# TMDB API call failed for ID tt19356070: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19356070?api_key=946e197c2070e68dcce7690ad471f676
# [24853] No data for IMDb ID: tt19356070
# TMDB API call failed for ID tt1935788: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1935788?api_key=946e197c2070e68dcce7690ad471f676
# [24857] No data for IMDb ID: tt1935788
# TMDB API call failed for ID tt1935793: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1935793?api_key=946e197c2070e68dcce7690ad471f676
# [24860] No data for IMDb ID: tt1935793
# TMDB API call failed for ID tt19358444: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19358444?api_key=946e197c2070e68dcce7690ad471f676
# [24867] No data for IMDb ID: tt19358444
# TMDB API call failed for ID tt19358832: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19358832?api_key=946e197c2070e68dcce7690ad471f676
# [24874] No data for IMDb ID: tt19358832
# TMDB API call failed for ID tt19359734: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19359734?api_key=946e197c2070e68dcce7690ad471f676
# [24882] No data for IMDb ID: tt19359734
# TMDB API call failed for ID tt19363430: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19363430?api_key=946e197c2070e68dcce7690ad471f676
# [24883] No data for IMDb ID: tt19363430
# TMDB API call failed for ID tt19363622: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19363622?api_key=946e197c2070e68dcce7690ad471f676
# [24884] No data for IMDb ID: tt19363622
# TMDB API call failed for ID tt19360832: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19360832?api_key=946e197c2070e68dcce7690ad471f676
# [24885] No data for IMDb ID: tt19360832
# TMDB API call failed for ID tt19361840: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19361840?api_key=946e197c2070e68dcce7690ad471f676
# [24886] No data for IMDb ID: tt19361840
# TMDB API call failed for ID tt19363684: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19363684?api_key=946e197c2070e68dcce7690ad471f676
# [24890] No data for IMDb ID: tt19363684
# TMDB API call failed for ID tt19363246: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19363246?api_key=946e197c2070e68dcce7690ad471f676
# [24891] No data for IMDb ID: tt19363246
# TMDB API call failed for ID tt19365626: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19365626?api_key=946e197c2070e68dcce7690ad471f676
# [24893] No data for IMDb ID: tt19365626
# TMDB API call failed for ID tt19364004: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19364004?api_key=946e197c2070e68dcce7690ad471f676
# [24896] No data for IMDb ID: tt19364004
# TMDB API call failed for ID tt19366466: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19366466?api_key=946e197c2070e68dcce7690ad471f676
# [24900] No data for IMDb ID: tt19366466
# TMDB API call failed for ID tt19365496: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19365496?api_key=946e197c2070e68dcce7690ad471f676
# [24901] No data for IMDb ID: tt19365496
# TMDB API call failed for ID tt19369380: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19369380?api_key=946e197c2070e68dcce7690ad471f676
# [24902] No data for IMDb ID: tt19369380
# TMDB API call failed for ID tt19369478: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19369478?api_key=946e197c2070e68dcce7690ad471f676
# [24908] No data for IMDb ID: tt19369478
# TMDB API call failed for ID tt19369662: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19369662?api_key=946e197c2070e68dcce7690ad471f676
# [24909] No data for IMDb ID: tt19369662
# TMDB API call failed for ID tt19369732: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19369732?api_key=946e197c2070e68dcce7690ad471f676
# [24911] No data for IMDb ID: tt19369732
# TMDB API call failed for ID tt1937101: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937101?api_key=946e197c2070e68dcce7690ad471f676
# [24912] No data for IMDb ID: tt1937101
# TMDB API call failed for ID tt19371446: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19371446?api_key=946e197c2070e68dcce7690ad471f676
# [24917] No data for IMDb ID: tt19371446
# TMDB API call failed for ID tt19371532: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19371532?api_key=946e197c2070e68dcce7690ad471f676
# [24920] No data for IMDb ID: tt19371532
# TMDB API call failed for ID tt1937132: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937132?api_key=946e197c2070e68dcce7690ad471f676
# [24922] No data for IMDb ID: tt1937132
# TMDB API call failed for ID tt1937260: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937260?api_key=946e197c2070e68dcce7690ad471f676
# [24930] No data for IMDb ID: tt1937260
# TMDB API call failed for ID tt19372826: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19372826?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt1937278: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937278?api_key=946e197c2070e68dcce7690ad471f676
# [24935] No data for IMDb ID: tt19372826
# [24936] No data for IMDb ID: tt1937278
# TMDB API call failed for ID tt19374102: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19374102?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt1937441: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937441?api_key=946e197c2070e68dcce7690ad471f676
# [24944] No data for IMDb ID: tt19374102
# [24945] No data for IMDb ID: tt1937441
# TMDB API call failed for ID tt1937493: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937493?api_key=946e197c2070e68dcce7690ad471f676
# [24949] No data for IMDb ID: tt1937493
# TMDB API call failed for ID tt1937502: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937502?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt19381394: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19381394?api_key=946e197c2070e68dcce7690ad471f676
# [24953] No data for IMDb ID: tt1937502
# [24954] No data for IMDb ID: tt19381394
# TMDB API call failed for ID tt1937501: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1937501?api_key=946e197c2070e68dcce7690ad471f676
# [24956] No data for IMDb ID: tt1937501
# TMDB API call failed for ID tt19387076: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19387076?api_key=946e197c2070e68dcce7690ad471f676
# [24961] No data for IMDb ID: tt19387076
# TMDB API call failed for ID tt19387470: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19387470?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt19387510: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19387510?api_key=946e197c2070e68dcce7690ad471f676
# [24963] No data for IMDb ID: tt19387470
# [24964] No data for IMDb ID: tt19387510
# TMDB API call failed for ID tt19387538: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19387538?api_key=946e197c2070e68dcce7690ad471f676
# [24967] No data for IMDb ID: tt19387538
# TMDB API call failed for ID tt19388864: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19388864?api_key=946e197c2070e68dcce7690ad471f676
# [24969] No data for IMDb ID: tt19388864
# TMDB API call failed for ID tt19387588: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19387588?api_key=946e197c2070e68dcce7690ad471f676
# [24970] No data for IMDb ID: tt19387588
# TMDB API call failed for ID tt19389178: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19389178?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt19389938: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19389938?api_key=946e197c2070e68dcce7690ad471f676
# [24972] No data for IMDb ID: tt19389178
# [24973] No data for IMDb ID: tt19389938
# TMDB API call failed for ID tt19391308: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19391308?api_key=946e197c2070e68dcce7690ad471f676
# [24976] No data for IMDb ID: tt19391308
# TMDB API call failed for ID tt19390220: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19390220?api_key=946e197c2070e68dcce7690ad471f676
# [24978] No data for IMDb ID: tt19390220
# TMDB API call failed for ID tt19392042: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19392042?api_key=946e197c2070e68dcce7690ad471f676
# [24981] No data for IMDb ID: tt19392042
# TMDB API call failed for ID tt19390502: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19390502?api_key=946e197c2070e68dcce7690ad471f676
# [24982] No data for IMDb ID: tt19390502
# TMDB API call failed for ID tt19394258: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19394258?api_key=946e197c2070e68dcce7690ad471f676
# [24986] No data for IMDb ID: tt19394258
# TMDB API call failed for ID tt19394770: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19394770?api_key=946e197c2070e68dcce7690ad471f676
# TMDB API call failed for ID tt19394362: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19394362?api_key=946e197c2070e68dcce7690ad471f676
# [24987] No data for IMDb ID: tt19394770
# [24988] No data for IMDb ID: tt19394362
# TMDB API call failed for ID tt19396262: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19396262?api_key=946e197c2070e68dcce7690ad471f676
# [24989] No data for IMDb ID: tt19396262
# TMDB API call failed for ID tt19394320: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19394320?api_key=946e197c2070e68dcce7690ad471f676
# [24992] No data for IMDb ID: tt19394320
# TMDB API call failed for ID tt19396146: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19396146?api_key=946e197c2070e68dcce7690ad471f676
# [24993] No data for IMDb ID: tt19396146
# TMDB API call failed for ID tt19396532: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19396532?api_key=946e197c2070e68dcce7690ad471f676
# [24994] No data for IMDb ID: tt19396532
# TMDB API call failed for ID tt19395374: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19395374?api_key=946e197c2070e68dcce7690ad471f676
# [24995] No data for IMDb ID: tt19395374
# TMDB API call failed for ID tt19395682: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt19395682?api_key=946e197c2070e68dcce7690ad471f676
# [24998] No data for IMDb ID: tt19395682
# TMDB API call failed for ID tt1939650: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1939650?api_key=946e197c2070e68dcce7690ad471f676
# [24999] No data for IMDb ID: tt1939650
# Finished TMDB API Data Collection (mapping). Total requests made: 11994
# Creating IMDb-TMDB ID mapping...
# Starting TMDB Stats Collection...
# Mapping file not found. Please run the mapping step first.
# Transforming TMDB JSON responses...
# No data found to transform.
